# %%
# !git clone https://github.com/ZhangNguyen/Human_Preference_Responses.git

# %%
# %cd /kaggle/working/Human_Preference_Responses

# %%
# !git pull origin main

# %%
import os
os.environ["PYTHONPATH"] = "/kaggle/working/Human_Preference_Responses"

# %%
pip install -U "transformers==4.45.2" "trl==0.11.4" "peft==0.13.2" "accelerate==0.34.2"

# %%
# !python scripts/prepared_data.py

# %%
# !python scripts/train_sft.py

# %%
# !python scripts/train_dpo.py

# %%
# !python -m scripts.merge_and_save

# %%
# !python scripts/zip_model.py
