# %%
# !pip install -q transformers datasets accelerate bitsandbytes evaluate tqdm

# %%
# !pip install -q lm-eval

# %%
import os
os.environ["PYTHONPATH"] = "/kaggle/working/Human_Preference_Responses"

# %%
# !python /kaggle/working/Human_Preference_Responses/benchmark/benchmark_suite.py \
  --finetuned_model "/kaggle/input/datasets/khanhnguyen264/model-finetune-humanpreferences" \
  --output_dir "/kaggle/working/benchmark_outputs" \
  --benchmarks mmlu gsm8k truthfulqa_mc2 \
  --lm_limit 50
